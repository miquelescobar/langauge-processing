# %%
from types import SimpleNamespace
from collections import Counter
import os
import re
import pathlib
import array
import pickle
import numpy as np
import torch
import torch.nn as nn
import pandas as pd

# %%
DATASET_VERSION = 'ca-100'
COMPETITION_ROOT = '../input/vectors'
DATASET_ROOT = f'../input/cbow-preprocessing/data/{DATASET_VERSION}'
WORKING_ROOT = f'data/{DATASET_VERSION}'
DATASET_PREFIX = 'ca.wiki'

# %%
params = SimpleNamespace(
    embedding_dim = 100,
    window_size = 5,
    batch_size = 1000,
    epochs = 4,
    preprocessed = f'{DATASET_ROOT}/{DATASET_PREFIX}',
    working = f'{WORKING_ROOT}/{DATASET_PREFIX}',
    modelname = f'{WORKING_ROOT}/{DATASET_VERSION}',
    train = True
)

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    pathlib.Path('/content/drive/My Drive/POE/vectors').mkdir(parents=True, exist_ok=True)
    os.chdir('/content/drive/My Drive/POE/vectors')
except:
    pass

# %%
class Vocabulary(object):
    def __init__(self, pad_token='<pad>', unk_token='<unk>', eos_token='<eos>'):
        self.token2idx = {}
        self.idx2token = []
        self.pad_token = pad_token
        self.unk_token = unk_token
        self.eos_token = eos_token
        if pad_token is not None:
            self.pad_index = self.add_token(pad_token)
        if unk_token is not None:
            self.unk_index = self.add_token(unk_token)
        if eos_token is not None:
            self.eos_index = self.add_token(eos_token)

    def add_token(self, token):
        if token not in self.token2idx:
            self.idx2token.append(token)
            self.token2idx[token] = len(self.idx2token) - 1
        return self.token2idx[token]

    def get_index(self, token):
        if isinstance(token, str):
            return self.token2idx.get(token, self.unk_index)
        else:
            return [self.token2idx.get(t, self.unk_index) for t in token]

    def __len__(self):
        return len(self.idx2token)

    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.__dict__, f)

    def load(self, filename):
        with open(filename, 'rb') as f:
            self.__dict__.update(pickle.load(f))

# %%
def batch_generator(idata, target, batch_size, shuffle=True):
    nsamples = len(idata)
    if shuffle:
        perm = np.random.permutation(nsamples)
    else:
        perm = range(nsamples)

    for i in range(0, nsamples, batch_size):
        batch_idx = perm[i:i+batch_size]
        if target is not None:
            yield idata[batch_idx], target[batch_idx]
        else:
            yield idata[batch_idx], None

# %% [markdown]
# CBOW model
# ----------
# You can add new parameters to the model in the *\_\_init\_\_()* method with *self.register_buffer()* (for parameters not to be trained):
#
#     self.register_buffer('position_weight', torch.tensor([1,2,2,1], dtype=torch.float32))
#
# or *nn.Parameter()* (for parameters to be trained)
#
#     self.position_weight = nn.Parameter(torch.tensor([1,2,2,1], dtype=torch.float32))
#
# In both cases, you can reference and use them in the *forward* method as
#
#     self.position_weight

# %%
class CBOW(nn.Module):
    def _init_(self, num_embeddings, embedding_dim):
        super()._init_()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)

    # B = Batch size
    # W = Number of context words (left + right)
    # E = embedding_dim
    # V = num_embeddings (number of words)
    def forward(self, input):
        # input shape is (B, W)
        e = self.emb(input)
        # e shape is (B, W, E)
        u = e.sum(dim=1)
        # u shape is (B, E)
        v = self.lin(u)
        # v shape is (B, V)
        return v

# %%
class CBOWa(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.register_buffer('position_weight', torch.tensor([1,2,2,1], dtype=torch.float32))

    def forward(self, inputs): #Inputs és l'índex de la paraula. Amb nn.Embedding la passem a un vector?
        # B * W1
        U = (self.emb(inputs) * self.position_weight.view(1,4,1)).sum(dim=1)
        
        # B * E
        V = self.lin(U)
        # B * V
        return V

# %%
class CBOWb(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.position_weight = nn.Parameter(torch.tensor([1,2,2,1], dtype=torch.float32))

    def forward(self, inputs): #Inputs és l'índex de la paraula. Amb nn.Embedding la passem a un vector?
        # B * W1
        U = (self.emb(inputs) * self.position_weight.view(1,4,1)).sum(dim=1)
        
        # B * E
        V = self.lin(U)
        # B * V
        return V

# %%
c_params = [[1 for i in range(params.embedding_dim)] for j in range(params.window_size-1)]

# %%
class CBOWc(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.position_weight = nn.Parameter(torch.tensor(c_params, dtype=torch.float32))

    def forward(self, inputs): #Inputs és l'índex de la paraula. Amb nn.Embedding la passem a un vector?
        # B * W1
        U = (self.emb(inputs) * self.position_weight.view(1,4,-1)).sum(dim=1)
        
        # B * E
        V = self.lin(U)
        # B * V
        return V

# %%
def load_preprocessed_dataset(prefix):
    # Try loading precomputed vocabulary and preprocessed data files
    token_vocab = Vocabulary()
    token_vocab.load(f'{prefix}.vocab')
    data = []
    for part in ['train', 'valid', 'test']:
        with np.load(f'{prefix}.{part}.npz') as set_data:
            idata, target = set_data['idata'], set_data['target']
            data.append((idata, target))
            print(f'Number of samples ({part}): {len(target)}')
    print("Using precomputed vocabulary and data files")
    print(f'Vocabulary size: {len(token_vocab)}')
    return token_vocab, data

# %%
def train(model, criterion, optimizer, idata, target, batch_size, device, log=False):
    model.train()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    for X, y in batch_generator(idata, target, batch_size, shuffle=True):
        # Get input and target sequences from batch
        X = torch.tensor(X, dtype=torch.long, device=device)
        y = torch.tensor(y, dtype=torch.long, device=device)

        model.zero_grad()
        output = model(X)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        # Training statistics
        total_loss += loss.item()
        ncorrect += (torch.max(output, 1)[1] == y).sum().item()
        ntokens += y.numel()
        niterations += 1
        if niterations == 200 or niterations == 500 or niterations % 1000 == 0:
            print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={100*ncorrect/ntokens:.1f}, loss={total_loss/ntokens:.2f}')

    total_loss = total_loss / ntokens
    accuracy = 100 * ncorrect / ntokens
    if log:
        print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={accuracy:.1f}, loss={total_loss:.2f}')
    return accuracy, total_loss

# %%
def validate(model, criterion, idata, target, batch_size, device):
    model.eval()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    y_pred = []
    for X, y in batch_generator(idata, target, batch_size, shuffle=False):
        # Get input and target sequences from batch
        X = torch.tensor(X, dtype=torch.long, device=device)
        output = model(X)
        if target is not None:
            y = torch.tensor(y, dtype=torch.long, device=device)
            loss = criterion(output, y)
            total_loss += loss.item()
            ncorrect += (torch.max(output, 1)[1] == y).sum().item()
            ntokens += y.numel()
            niterations += 1
        else:
            pred = torch.max(output, 1)[1].detach().to('cpu').numpy()
            y_pred.append(pred)

    if target is not None:
        total_loss = total_loss / ntokens
        accuracy = 100 * ncorrect / ntokens
        return accuracy, total_loss
    else:
        return np.concatenate(y_pred)

# %%
# Create working dir
pathlib.Path(WORKING_ROOT).mkdir(parents=True, exist_ok=True)

# %%
# Select device
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print("WARNING: Training without GPU can be very slow!")

# %%
vocab, data = load_preprocessed_dataset(params.preprocessed)
# Out:
# Number of samples (train): 80234403
# Number of samples (valid): 163012
# Number of samples (test): 164055
# Using precomputed vocabulary and data files
# Vocabulary size: 100002

# %%
# 'El Periodico' validation dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_valid.csv')
tokens = valid_x_df.columns[1:]
valid_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')
valid_y_df = pd.read_csv(f'{COMPETITION_ROOT}/y_valid.csv')
valid_y = valid_y_df['token'].apply(vocab.get_index).to_numpy(dtype='int32')

# %%
mm = CBOW()
dir(mm)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_name',
#  '_init_',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_tracing_name',
#  '_version',
#  'add_module',
#  'apply',
#  'buffers',
#  'children',
#  'cpu',
#  'cuda',
#  'double',
#  'dump_patches',
#  'eval',
#  'extra_repr',
#  'float',
#  'forward',
#  'half',
#  'load_state_dict',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'parameters',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_parameter',
#  'requires_grad_',
#  'share_memory',
#  'state_dict',
#  'to',
#  'train',
#  'training',
#  'type',
#  'zero_grad']

# %%
models = {
    'a' : CBOWa(num_embeddings=len(vocab), embedding_dim=params.embedding_dim),
    'b' : CBOWb(num_embeddings=len(vocab), embedding_dim=params.embedding_dim),
    'c' : CBOWc(num_embeddings=len(vocab), embedding_dim=params.embedding_dim)
}

# %%
for model_type, model in models.items():
    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters())
    criterion = nn.CrossEntropyLoss(reduction='sum')

    train_accuracy = []
    wiki_accuracy = []
    valid_accuracy = []
    for epoch in range(params.epochs):
        acc, loss = train(model, criterion, optimizer, data[0][0], data[0][1], params.batch_size, device, log=True)
        train_accuracy.append(acc)
        print(f'| epoch {epoch:03d} | train accuracy={acc:.1f}%, train loss={loss:.2f}')
        acc, loss = validate(model, criterion, data[1][0], data[1][1], params.batch_size, device)
        wiki_accuracy.append(acc)
        print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (wikipedia)')
        acc, loss = validate(model, criterion, valid_x, valid_y, params.batch_size, device)
        valid_accuracy.append(acc)
        print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (El Periódico)')

    # Save model
    torch.save(model.state_dict(), f'{params.modelname}_{model_type}.pt')
# Out:
# Train: wpb=1000, num_updates=200, accuracy=3.6, loss=9.93
# Train: wpb=1000, num_updates=500, accuracy=6.1, loss=8.84
# Train: wpb=1000, num_updates=1000, accuracy=8.5, loss=8.06
# Train: wpb=1000, num_updates=2000, accuracy=11.0, loss=7.36
# Train: wpb=1000, num_updates=3000, accuracy=12.7, loss=7.01
# Train: wpb=1000, num_updates=4000, accuracy=13.9, loss=6.78
# Train: wpb=1000, num_updates=5000, accuracy=14.9, loss=6.61
# Train: wpb=1000, num_updates=6000, accuracy=15.7, loss=6.49
# Train: wpb=1000, num_updates=7000, accuracy=16.4, loss=6.38
# Train: wpb=1000, num_updates=8000, accuracy=17.0, loss=6.29
# Train: wpb=1000, num_updates=9000, accuracy=17.6, loss=6.22
# Train: wpb=1000, num_updates=10000, accuracy=18.0, loss=6.15
# Train: wpb=1000, num_updates=11000, accuracy=18.5, loss=6.09
# Train: wpb=1000, num_updates=12000, accuracy=18.9, loss=6.04
# Train: wpb=1000, num_updates=13000, accuracy=19.2, loss=6.00
# Train: wpb=1000, num_updates=14000, accuracy=19.5, loss=5.96
# Train: wpb=1000, num_updates=15000, accuracy=19.8, loss=5.92
# Train: wpb=1000, num_updates=16000, accuracy=20.1, loss=5.88
# Train: wpb=1000, num_updates=17000, accuracy=20.4, loss=5.85
# Train: wpb=1000, num_updates=18000, accuracy=20.6, loss=5.82
# Train: wpb=1000, num_updates=19000, accuracy=20.8, loss=5.79
# Train: wpb=1000, num_updates=20000, accuracy=21.1, loss=5.77
# Train: wpb=1000, num_updates=21000, accuracy=21.3, loss=5.74
# Train: wpb=1000, num_updates=22000, accuracy=21.4, loss=5.72
# Train: wpb=1000, num_updates=23000, accuracy=21.6, loss=5.70
# Train: wpb=1000, num_updates=24000, accuracy=21.8, loss=5.68
# Train: wpb=1000, num_updates=25000, accuracy=22.0, loss=5.66
# Train: wpb=1000, num_updates=26000, accuracy=22.1, loss=5.64
# Train: wpb=1000, num_updates=27000, accuracy=22.3, loss=5.62
# Train: wpb=1000, num_updates=28000, accuracy=22.4, loss=5.60
# Train: wpb=1000, num_updates=29000, accuracy=22.5, loss=5.59
# Train: wpb=1000, num_updates=30000, accuracy=22.6, loss=5.57
# Train: wpb=1000, num_updates=31000, accuracy=22.8, loss=5.56
# Train: wpb=1000, num_updates=32000, accuracy=22.9, loss=5.54
# Train: wpb=1000, num_updates=33000, accuracy=23.0, loss=5.53
# Train: wpb=1000, num_updates=34000, accuracy=23.1, loss=5.51
# Train: wpb=1000, num_updates=35000, accuracy=23.2, loss=5.50
# Train: wpb=1000, num_updates=36000, accuracy=23.3, loss=5.49
# Train: wpb=1000, num_updates=37000, accuracy=23.4, loss=5.48
# Train: wpb=1000, num_updates=38000, accuracy=23.5, loss=5.47
# Train: wpb=1000, num_updates=39000, accuracy=23.6, loss=5.45
# Train: wpb=1000, num_updates=40000, accuracy=23.7, loss=5.44
# Train: wpb=1000, num_updates=41000, accuracy=23.8, loss=5.43
# Train: wpb=1000, num_updates=42000, accuracy=23.8, loss=5.42
# Train: wpb=1000, num_updates=43000, accuracy=23.9, loss=5.41
# Train: wpb=1000, num_updates=44000, accuracy=24.0, loss=5.40
# Train: wpb=1000, num_updates=45000, accuracy=24.1, loss=5.40
# Train: wpb=1000, num_updates=46000, accuracy=24.1, loss=5.39
# Train: wpb=1000, num_updates=47000, accuracy=24.2, loss=5.38
# Train: wpb=1000, num_updates=48000, accuracy=24.3, loss=5.37
# Train: wpb=1000, num_updates=49000, accuracy=24.3, loss=5.36
# Train: wpb=1000, num_updates=50000, accuracy=24.4, loss=5.35
# Train: wpb=1000, num_updates=51000, accuracy=24.5, loss=5.34
# Train: wpb=1000, num_updates=52000, accuracy=24.5, loss=5.34
# Train: wpb=1000, num_updates=53000, accuracy=24.6, loss=5.33
# Train: wpb=1000, num_updates=54000, accuracy=24.6, loss=5.32
# Train: wpb=1000, num_updates=55000, accuracy=24.7, loss=5.32
# Train: wpb=1000, num_updates=56000, accuracy=24.8, loss=5.31
# Train: wpb=1000, num_updates=57000, accuracy=24.8, loss=5.30
# Train: wpb=1000, num_updates=58000, accuracy=24.9, loss=5.30
# Train: wpb=1000, num_updates=59000, accuracy=24.9, loss=5.29
# Train: wpb=1000, num_updates=60000, accuracy=25.0, loss=5.28
# Train: wpb=1000, num_updates=61000, accuracy=25.0, loss=5.28
# Train: wpb=1000, num_updates=62000, accuracy=25.1, loss=5.27
# Train: wpb=1000, num_updates=63000, accuracy=25.1, loss=5.26
# Train: wpb=1000, num_updates=64000, accuracy=25.2, loss=5.26
# Train: wpb=1000, num_updates=65000, accuracy=25.2, loss=5.25
# Train: wpb=1000, num_updates=66000, accuracy=25.2, loss=5.25
# Train: wpb=1000, num_updates=67000, accuracy=25.3, loss=5.24
# Train: wpb=1000, num_updates=68000, accuracy=25.3, loss=5.24
# Train: wpb=1000, num_updates=69000, accuracy=25.4, loss=5.23
# Train: wpb=1000, num_updates=70000, accuracy=25.4, loss=5.23
# Train: wpb=1000, num_updates=71000, accuracy=25.4, loss=5.22
# Train: wpb=1000, num_updates=72000, accuracy=25.5, loss=5.22
# Train: wpb=1000, num_updates=73000, accuracy=25.5, loss=5.21
# Train: wpb=1000, num_updates=74000, accuracy=25.6, loss=5.21
# Train: wpb=1000, num_updates=75000, accuracy=25.6, loss=5.20
# Train: wpb=1000, num_updates=76000, accuracy=25.6, loss=5.20
# Train: wpb=1000, num_updates=77000, accuracy=25.7, loss=5.19
# Train: wpb=1000, num_updates=78000, accuracy=25.7, loss=5.19
# Train: wpb=1000, num_updates=79000, accuracy=25.7, loss=5.18
# Train: wpb=1000, num_updates=80000, accuracy=25.8, loss=5.18
# Train: wpb=999, num_updates=80235, accuracy=25.8, loss=5.18
# | epoch 000 | train accuracy=25.8%, train loss=5.18
# | epoch 000 | valid accuracy=28.5%, valid loss=4.78 (wikipedia)
# | epoch 000 | valid accuracy=22.3%, valid loss=5.58 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=28.7, loss=4.76
# Train: wpb=1000, num_updates=500, accuracy=28.7, loss=4.75
# Train: wpb=1000, num_updates=1000, accuracy=28.7, loss=4.75
# Train: wpb=1000, num_updates=2000, accuracy=28.7, loss=4.75
# Train: wpb=1000, num_updates=3000, accuracy=28.7, loss=4.76
# Train: wpb=1000, num_updates=4000, accuracy=28.7, loss=4.76
# Train: wpb=1000, num_updates=5000, accuracy=28.7, loss=4.76
# Train: wpb=1000, num_updates=6000, accuracy=28.7, loss=4.76
# Train: wpb=1000, num_updates=7000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=8000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=9000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=10000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=11000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=12000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=13000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=14000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=15000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=16000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=17000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=18000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=19000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=20000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=21000, accuracy=28.7, loss=4.77
# Train: wpb=1000, num_updates=22000, accuracy=28.8, loss=4.77
# Train: wpb=1000, num_updates=23000, accuracy=28.8, loss=4.77
# Train: wpb=1000, num_updates=24000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=25000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=26000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=27000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=28000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=29000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=30000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=31000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=32000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=33000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=34000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=35000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=36000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=37000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=38000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=39000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=40000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=41000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=42000, accuracy=28.8, loss=4.76
# Train: wpb=1000, num_updates=43000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=44000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=45000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=46000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=47000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=48000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=49000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=50000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=51000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=52000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=53000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=54000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=55000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=56000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=57000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=58000, accuracy=28.9, loss=4.75
# Train: wpb=1000, num_updates=59000, accuracy=28.9, loss=4.74
# Train: wpb=1000, num_updates=60000, accuracy=28.9, loss=4.74
# Train: wpb=1000, num_updates=61000, accuracy=28.9, loss=4.74
# Train: wpb=1000, num_updates=62000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=63000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=64000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=65000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=66000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=67000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=68000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=69000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=70000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=71000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=72000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=73000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=74000, accuracy=29.0, loss=4.74
# Train: wpb=1000, num_updates=75000, accuracy=29.0, loss=4.73
# Train: wpb=1000, num_updates=76000, accuracy=29.0, loss=4.73
# Train: wpb=1000, num_updates=77000, accuracy=29.0, loss=4.73
# Train: wpb=1000, num_updates=78000, accuracy=29.0, loss=4.73
# Train: wpb=1000, num_updates=79000, accuracy=29.0, loss=4.73
# Train: wpb=1000, num_updates=80000, accuracy=29.0, loss=4.73
# Train: wpb=999, num_updates=80235, accuracy=29.0, loss=4.73
# | epoch 001 | train accuracy=29.0%, train loss=4.73
# | epoch 001 | valid accuracy=29.3%, valid loss=4.65 (wikipedia)
# | epoch 001 | valid accuracy=22.9%, valid loss=5.48 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=29.8, loss=4.59
# Train: wpb=1000, num_updates=500, accuracy=29.7, loss=4.60
# Train: wpb=1000, num_updates=1000, accuracy=29.6, loss=4.60
# Train: wpb=1000, num_updates=2000, accuracy=29.6, loss=4.61
# Train: wpb=1000, num_updates=3000, accuracy=29.6, loss=4.61
# Train: wpb=1000, num_updates=4000, accuracy=29.6, loss=4.61
# Train: wpb=1000, num_updates=5000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=6000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=7000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=8000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=9000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=10000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=11000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=12000, accuracy=29.6, loss=4.62
# Train: wpb=1000, num_updates=13000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=14000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=15000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=16000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=17000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=18000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=19000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=20000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=21000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=22000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=23000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=24000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=25000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=26000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=27000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=28000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=29000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=30000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=31000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=32000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=33000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=34000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=35000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=36000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=37000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=38000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=39000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=40000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=41000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=42000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=43000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=44000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=45000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=46000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=47000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=48000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=49000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=50000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=51000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=52000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=53000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=54000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=55000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=56000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=57000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=58000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=59000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=60000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=61000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=62000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=63000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=64000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=65000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=66000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=67000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=68000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=69000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=70000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=71000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=72000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=73000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=74000, accuracy=29.6, loss=4.63
# Train: wpb=1000, num_updates=75000, accuracy=29.7, loss=4.63
# Train: wpb=1000, num_updates=76000, accuracy=29.7, loss=4.63
# Train: wpb=1000, num_updates=77000, accuracy=29.7, loss=4.63
# Train: wpb=1000, num_updates=78000, accuracy=29.7, loss=4.63
# Train: wpb=1000, num_updates=79000, accuracy=29.7, loss=4.63
# Train: wpb=1000, num_updates=80000, accuracy=29.7, loss=4.63
# Train: wpb=999, num_updates=80235, accuracy=29.7, loss=4.63
# | epoch 002 | train accuracy=29.7%, train loss=4.63
# | epoch 002 | valid accuracy=29.6%, valid loss=4.60 (wikipedia)
# | epoch 002 | valid accuracy=23.1%, valid loss=5.44 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=30.1, loss=4.53
# Train: wpb=1000, num_updates=500, accuracy=30.0, loss=4.53
# Train: wpb=1000, num_updates=1000, accuracy=30.0, loss=4.54
# Train: wpb=1000, num_updates=2000, accuracy=30.0, loss=4.54
# Train: wpb=1000, num_updates=3000, accuracy=30.0, loss=4.54
# Train: wpb=1000, num_updates=4000, accuracy=30.1, loss=4.54
# Train: wpb=1000, num_updates=5000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=6000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=7000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=8000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=9000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=10000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=11000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=12000, accuracy=30.0, loss=4.55
# Train: wpb=1000, num_updates=13000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=14000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=15000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=16000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=17000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=18000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=19000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=20000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=21000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=22000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=23000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=24000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=25000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=26000, accuracy=30.0, loss=4.56
# Train: wpb=1000, num_updates=27000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=28000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=29000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=30000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=31000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=32000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=33000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=34000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=35000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=36000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=37000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=38000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=39000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=40000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=41000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=42000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=43000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=44000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=45000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=46000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=47000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=48000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=49000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=50000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=51000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=52000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=53000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=54000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=55000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=56000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=57000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=58000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=59000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=60000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=61000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=62000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=63000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=64000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=65000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=66000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=67000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=68000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=69000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=70000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=71000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=72000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=73000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=74000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=75000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=76000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=77000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=78000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=79000, accuracy=30.0, loss=4.57
# Train: wpb=1000, num_updates=80000, accuracy=30.0, loss=4.57
# Train: wpb=999, num_updates=80235, accuracy=30.0, loss=4.57
# | epoch 003 | train accuracy=30.0%, train loss=4.57
# | epoch 003 | valid accuracy=29.7%, valid loss=4.57 (wikipedia)
# | epoch 003 | valid accuracy=23.3%, valid loss=5.42 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=3.6, loss=9.92
# Train: wpb=1000, num_updates=500, accuracy=6.1, loss=8.83
# Train: wpb=1000, num_updates=1000, accuracy=8.4, loss=8.06
# Train: wpb=1000, num_updates=2000, accuracy=11.0, loss=7.34
# Train: wpb=1000, num_updates=3000, accuracy=12.8, loss=6.96
# Train: wpb=1000, num_updates=4000, accuracy=14.1, loss=6.72
# Train: wpb=1000, num_updates=5000, accuracy=15.2, loss=6.55
# Train: wpb=1000, num_updates=6000, accuracy=16.0, loss=6.41
# Train: wpb=1000, num_updates=7000, accuracy=16.8, loss=6.30
# Train: wpb=1000, num_updates=8000, accuracy=17.5, loss=6.21
# Train: wpb=1000, num_updates=9000, accuracy=18.0, loss=6.13
# Train: wpb=1000, num_updates=10000, accuracy=18.5, loss=6.06
# Train: wpb=1000, num_updates=11000, accuracy=19.0, loss=6.01
# Train: wpb=1000, num_updates=12000, accuracy=19.4, loss=5.95
# Train: wpb=1000, num_updates=13000, accuracy=19.8, loss=5.91
# Train: wpb=1000, num_updates=14000, accuracy=20.1, loss=5.86
# Train: wpb=1000, num_updates=15000, accuracy=20.4, loss=5.82
# Train: wpb=1000, num_updates=16000, accuracy=20.7, loss=5.79
# Train: wpb=1000, num_updates=17000, accuracy=21.0, loss=5.75
# Train: wpb=1000, num_updates=18000, accuracy=21.2, loss=5.72
# Train: wpb=1000, num_updates=19000, accuracy=21.5, loss=5.69
# Train: wpb=1000, num_updates=20000, accuracy=21.7, loss=5.66
# Train: wpb=1000, num_updates=21000, accuracy=21.9, loss=5.64
# Train: wpb=1000, num_updates=22000, accuracy=22.1, loss=5.61
# Train: wpb=1000, num_updates=23000, accuracy=22.3, loss=5.59
# Train: wpb=1000, num_updates=24000, accuracy=22.5, loss=5.57
# Train: wpb=1000, num_updates=25000, accuracy=22.6, loss=5.55
# Train: wpb=1000, num_updates=26000, accuracy=22.8, loss=5.53
# Train: wpb=1000, num_updates=27000, accuracy=23.0, loss=5.51
# Train: wpb=1000, num_updates=28000, accuracy=23.1, loss=5.50
# Train: wpb=1000, num_updates=29000, accuracy=23.2, loss=5.48
# Train: wpb=1000, num_updates=30000, accuracy=23.4, loss=5.46
# Train: wpb=1000, num_updates=31000, accuracy=23.5, loss=5.45
# Train: wpb=1000, num_updates=32000, accuracy=23.6, loss=5.43
# Train: wpb=1000, num_updates=33000, accuracy=23.7, loss=5.42
# Train: wpb=1000, num_updates=34000, accuracy=23.9, loss=5.41
# Train: wpb=1000, num_updates=35000, accuracy=24.0, loss=5.39
# Train: wpb=1000, num_updates=36000, accuracy=24.1, loss=5.38
# Train: wpb=1000, num_updates=37000, accuracy=24.2, loss=5.37
# Train: wpb=1000, num_updates=38000, accuracy=24.3, loss=5.36
# Train: wpb=1000, num_updates=39000, accuracy=24.4, loss=5.34
# Train: wpb=1000, num_updates=40000, accuracy=24.4, loss=5.33
# Train: wpb=1000, num_updates=41000, accuracy=24.5, loss=5.32
# Train: wpb=1000, num_updates=42000, accuracy=24.6, loss=5.31
# Train: wpb=1000, num_updates=43000, accuracy=24.7, loss=5.30
# Train: wpb=1000, num_updates=44000, accuracy=24.8, loss=5.29
# Train: wpb=1000, num_updates=45000, accuracy=24.9, loss=5.28
# Train: wpb=1000, num_updates=46000, accuracy=24.9, loss=5.28
# Train: wpb=1000, num_updates=47000, accuracy=25.0, loss=5.27
# Train: wpb=1000, num_updates=48000, accuracy=25.1, loss=5.26
# Train: wpb=1000, num_updates=49000, accuracy=25.1, loss=5.25
# Train: wpb=1000, num_updates=50000, accuracy=25.2, loss=5.24
# Train: wpb=1000, num_updates=51000, accuracy=25.3, loss=5.23
# Train: wpb=1000, num_updates=52000, accuracy=25.3, loss=5.23
# Train: wpb=1000, num_updates=53000, accuracy=25.4, loss=5.22
# Train: wpb=1000, num_updates=54000, accuracy=25.5, loss=5.21
# Train: wpb=1000, num_updates=55000, accuracy=25.5, loss=5.20
# Train: wpb=1000, num_updates=56000, accuracy=25.6, loss=5.20
# Train: wpb=1000, num_updates=57000, accuracy=25.6, loss=5.19
# Train: wpb=1000, num_updates=58000, accuracy=25.7, loss=5.18
# Train: wpb=1000, num_updates=59000, accuracy=25.7, loss=5.18
# Train: wpb=1000, num_updates=60000, accuracy=25.8, loss=5.17
# Train: wpb=1000, num_updates=61000, accuracy=25.8, loss=5.16
# Train: wpb=1000, num_updates=62000, accuracy=25.9, loss=5.16
# Train: wpb=1000, num_updates=63000, accuracy=25.9, loss=5.15
# Train: wpb=1000, num_updates=64000, accuracy=26.0, loss=5.15
# Train: wpb=1000, num_updates=65000, accuracy=26.0, loss=5.14
# Train: wpb=1000, num_updates=66000, accuracy=26.1, loss=5.13
# Train: wpb=1000, num_updates=67000, accuracy=26.1, loss=5.13
# Train: wpb=1000, num_updates=68000, accuracy=26.2, loss=5.12
# Train: wpb=1000, num_updates=69000, accuracy=26.2, loss=5.12
# Train: wpb=1000, num_updates=70000, accuracy=26.3, loss=5.11
# Train: wpb=1000, num_updates=71000, accuracy=26.3, loss=5.11
# Train: wpb=1000, num_updates=72000, accuracy=26.3, loss=5.10
# Train: wpb=1000, num_updates=73000, accuracy=26.4, loss=5.10
# Train: wpb=1000, num_updates=74000, accuracy=26.4, loss=5.09
# Train: wpb=1000, num_updates=75000, accuracy=26.4, loss=5.09
# Train: wpb=1000, num_updates=76000, accuracy=26.5, loss=5.08
# Train: wpb=1000, num_updates=77000, accuracy=26.5, loss=5.08
# Train: wpb=1000, num_updates=78000, accuracy=26.6, loss=5.08
# Train: wpb=1000, num_updates=79000, accuracy=26.6, loss=5.07
# Train: wpb=1000, num_updates=80000, accuracy=26.6, loss=5.07
# Train: wpb=999, num_updates=80235, accuracy=26.6, loss=5.07
# | epoch 000 | train accuracy=26.6%, train loss=5.07
# | epoch 000 | valid accuracy=29.6%, valid loss=4.65 (wikipedia)
# | epoch 000 | valid accuracy=23.3%, valid loss=5.43 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=29.7, loss=4.64
# Train: wpb=1000, num_updates=500, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=1000, accuracy=29.6, loss=4.65
# Train: wpb=1000, num_updates=2000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=3000, accuracy=29.6, loss=4.65
# Train: wpb=1000, num_updates=4000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=5000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=6000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=7000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=8000, accuracy=29.6, loss=4.66
# Train: wpb=1000, num_updates=9000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=10000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=11000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=12000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=13000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=14000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=15000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=16000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=17000, accuracy=29.7, loss=4.66
# Train: wpb=1000, num_updates=18000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=19000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=20000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=21000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=22000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=23000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=24000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=25000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=26000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=27000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=28000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=29000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=30000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=31000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=32000, accuracy=29.7, loss=4.65
# Train: wpb=1000, num_updates=33000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=34000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=35000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=36000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=37000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=38000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=39000, accuracy=29.8, loss=4.65
# Train: wpb=1000, num_updates=40000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=41000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=42000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=43000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=44000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=45000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=46000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=47000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=48000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=49000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=50000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=51000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=52000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=53000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=54000, accuracy=29.8, loss=4.64
# Train: wpb=1000, num_updates=55000, accuracy=29.9, loss=4.64
# Train: wpb=1000, num_updates=56000, accuracy=29.9, loss=4.64
# Train: wpb=1000, num_updates=57000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=58000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=59000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=60000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=61000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=62000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=63000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=64000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=65000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=66000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=67000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=68000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=69000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=70000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=71000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=72000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=73000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=74000, accuracy=29.9, loss=4.63
# Train: wpb=1000, num_updates=75000, accuracy=29.9, loss=4.62
# Train: wpb=1000, num_updates=76000, accuracy=29.9, loss=4.62
# Train: wpb=1000, num_updates=77000, accuracy=29.9, loss=4.62
# Train: wpb=1000, num_updates=78000, accuracy=29.9, loss=4.62
# Train: wpb=1000, num_updates=79000, accuracy=29.9, loss=4.62
# Train: wpb=1000, num_updates=80000, accuracy=30.0, loss=4.62
# Train: wpb=999, num_updates=80235, accuracy=30.0, loss=4.62
# | epoch 001 | train accuracy=30.0%, train loss=4.62
# | epoch 001 | valid accuracy=30.4%, valid loss=4.54 (wikipedia)
# | epoch 001 | valid accuracy=24.0%, valid loss=5.34 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=30.4, loss=4.53
# Train: wpb=1000, num_updates=500, accuracy=30.4, loss=4.52
# Train: wpb=1000, num_updates=1000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=2000, accuracy=30.4, loss=4.52
# Train: wpb=1000, num_updates=3000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=4000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=5000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=6000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=7000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=8000, accuracy=30.5, loss=4.52
# Train: wpb=1000, num_updates=9000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=10000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=11000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=12000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=13000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=14000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=15000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=16000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=17000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=18000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=19000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=20000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=21000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=22000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=23000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=24000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=25000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=26000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=27000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=28000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=29000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=30000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=31000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=32000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=33000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=34000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=35000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=36000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=37000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=38000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=39000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=40000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=41000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=42000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=43000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=44000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=45000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=46000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=47000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=48000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=49000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=50000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=51000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=52000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=53000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=54000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=55000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=56000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=57000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=58000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=59000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=60000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=61000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=62000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=63000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=64000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=65000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=66000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=67000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=68000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=69000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=70000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=71000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=72000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=73000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=74000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=75000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=76000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=77000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=78000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=79000, accuracy=30.5, loss=4.53
# Train: wpb=1000, num_updates=80000, accuracy=30.5, loss=4.53
# Train: wpb=999, num_updates=80235, accuracy=30.5, loss=4.53
# | epoch 002 | train accuracy=30.5%, train loss=4.53
# | epoch 002 | valid accuracy=30.6%, valid loss=4.49 (wikipedia)
# | epoch 002 | valid accuracy=24.0%, valid loss=5.31 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=31.0, loss=4.44
# Train: wpb=1000, num_updates=500, accuracy=31.0, loss=4.44
# Train: wpb=1000, num_updates=1000, accuracy=30.9, loss=4.45
# Train: wpb=1000, num_updates=2000, accuracy=30.9, loss=4.45
# Train: wpb=1000, num_updates=3000, accuracy=30.9, loss=4.45
# Train: wpb=1000, num_updates=4000, accuracy=30.9, loss=4.45
# Train: wpb=1000, num_updates=5000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=6000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=7000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=8000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=9000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=10000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=11000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=12000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=13000, accuracy=30.9, loss=4.46
# Train: wpb=1000, num_updates=14000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=15000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=16000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=17000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=18000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=19000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=20000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=21000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=22000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=23000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=24000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=25000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=26000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=27000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=28000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=29000, accuracy=30.9, loss=4.47
# Train: wpb=1000, num_updates=30000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=31000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=32000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=33000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=34000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=35000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=36000, accuracy=30.8, loss=4.47
# Train: wpb=1000, num_updates=37000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=38000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=39000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=40000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=41000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=42000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=43000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=44000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=45000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=46000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=47000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=48000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=49000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=50000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=51000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=52000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=53000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=54000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=55000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=56000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=57000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=58000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=59000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=60000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=61000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=62000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=63000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=64000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=65000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=66000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=67000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=68000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=69000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=70000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=71000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=72000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=73000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=74000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=75000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=76000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=77000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=78000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=79000, accuracy=30.8, loss=4.48
# Train: wpb=1000, num_updates=80000, accuracy=30.8, loss=4.48
# Train: wpb=999, num_updates=80235, accuracy=30.8, loss=4.48
# | epoch 003 | train accuracy=30.8%, train loss=4.48
# | epoch 003 | valid accuracy=30.8%, valid loss=4.46 (wikipedia)
# | epoch 003 | valid accuracy=24.0%, valid loss=5.29 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=3.5, loss=9.66
# Train: wpb=1000, num_updates=500, accuracy=6.2, loss=8.59
# Train: wpb=1000, num_updates=1000, accuracy=9.0, loss=7.82
# Train: wpb=1000, num_updates=2000, accuracy=12.5, loss=7.09
# Train: wpb=1000, num_updates=3000, accuracy=14.9, loss=6.70
# Train: wpb=1000, num_updates=4000, accuracy=16.7, loss=6.43
# Train: wpb=1000, num_updates=5000, accuracy=18.1, loss=6.23
# Train: wpb=1000, num_updates=6000, accuracy=19.2, loss=6.08
# Train: wpb=1000, num_updates=7000, accuracy=20.1, loss=5.95
# Train: wpb=1000, num_updates=8000, accuracy=21.0, loss=5.84
# Train: wpb=1000, num_updates=9000, accuracy=21.7, loss=5.75
# Train: wpb=1000, num_updates=10000, accuracy=22.3, loss=5.67
# Train: wpb=1000, num_updates=11000, accuracy=22.9, loss=5.60
# Train: wpb=1000, num_updates=12000, accuracy=23.5, loss=5.54
# Train: wpb=1000, num_updates=13000, accuracy=23.9, loss=5.48
# Train: wpb=1000, num_updates=14000, accuracy=24.4, loss=5.43
# Train: wpb=1000, num_updates=15000, accuracy=24.8, loss=5.38
# Train: wpb=1000, num_updates=16000, accuracy=25.1, loss=5.34
# Train: wpb=1000, num_updates=17000, accuracy=25.5, loss=5.30
# Train: wpb=1000, num_updates=18000, accuracy=25.8, loss=5.27
# Train: wpb=1000, num_updates=19000, accuracy=26.1, loss=5.23
# Train: wpb=1000, num_updates=20000, accuracy=26.4, loss=5.20
# Train: wpb=1000, num_updates=21000, accuracy=26.6, loss=5.17
# Train: wpb=1000, num_updates=22000, accuracy=26.9, loss=5.14
# Train: wpb=1000, num_updates=23000, accuracy=27.1, loss=5.11
# Train: wpb=1000, num_updates=24000, accuracy=27.4, loss=5.09
# Train: wpb=1000, num_updates=25000, accuracy=27.6, loss=5.06
# Train: wpb=1000, num_updates=26000, accuracy=27.8, loss=5.04
# Train: wpb=1000, num_updates=27000, accuracy=28.0, loss=5.02
# Train: wpb=1000, num_updates=28000, accuracy=28.2, loss=5.00
# Train: wpb=1000, num_updates=29000, accuracy=28.3, loss=4.98
# Train: wpb=1000, num_updates=30000, accuracy=28.5, loss=4.96
# Train: wpb=1000, num_updates=31000, accuracy=28.7, loss=4.94
# Train: wpb=1000, num_updates=32000, accuracy=28.8, loss=4.92
# Train: wpb=1000, num_updates=33000, accuracy=29.0, loss=4.91
# Train: wpb=1000, num_updates=34000, accuracy=29.1, loss=4.89
# Train: wpb=1000, num_updates=35000, accuracy=29.3, loss=4.88
# Train: wpb=1000, num_updates=36000, accuracy=29.4, loss=4.86
# Train: wpb=1000, num_updates=37000, accuracy=29.5, loss=4.85
# Train: wpb=1000, num_updates=38000, accuracy=29.6, loss=4.83
# Train: wpb=1000, num_updates=39000, accuracy=29.8, loss=4.82
# Train: wpb=1000, num_updates=40000, accuracy=29.9, loss=4.81
# Train: wpb=1000, num_updates=41000, accuracy=30.0, loss=4.79
# Train: wpb=1000, num_updates=42000, accuracy=30.1, loss=4.78
# Train: wpb=1000, num_updates=43000, accuracy=30.2, loss=4.77
# Train: wpb=1000, num_updates=44000, accuracy=30.3, loss=4.76
# Train: wpb=1000, num_updates=45000, accuracy=30.4, loss=4.75
# Train: wpb=1000, num_updates=46000, accuracy=30.5, loss=4.73
# Train: wpb=1000, num_updates=47000, accuracy=30.6, loss=4.72
# Train: wpb=1000, num_updates=48000, accuracy=30.7, loss=4.71
# Train: wpb=1000, num_updates=49000, accuracy=30.8, loss=4.70
# Train: wpb=1000, num_updates=50000, accuracy=30.9, loss=4.69
# Train: wpb=1000, num_updates=51000, accuracy=31.0, loss=4.68
# Train: wpb=1000, num_updates=52000, accuracy=31.0, loss=4.67
# Train: wpb=1000, num_updates=53000, accuracy=31.1, loss=4.67
# Train: wpb=1000, num_updates=54000, accuracy=31.2, loss=4.66
# Train: wpb=1000, num_updates=55000, accuracy=31.3, loss=4.65
# Train: wpb=1000, num_updates=56000, accuracy=31.4, loss=4.64
# Train: wpb=1000, num_updates=57000, accuracy=31.4, loss=4.63
# Train: wpb=1000, num_updates=58000, accuracy=31.5, loss=4.62
# Train: wpb=1000, num_updates=59000, accuracy=31.6, loss=4.62
# Train: wpb=1000, num_updates=60000, accuracy=31.6, loss=4.61
# Train: wpb=1000, num_updates=61000, accuracy=31.7, loss=4.60
# Train: wpb=1000, num_updates=62000, accuracy=31.8, loss=4.59
# Train: wpb=1000, num_updates=63000, accuracy=31.8, loss=4.59
# Train: wpb=1000, num_updates=64000, accuracy=31.9, loss=4.58
# Train: wpb=1000, num_updates=65000, accuracy=32.0, loss=4.57
# Train: wpb=1000, num_updates=66000, accuracy=32.0, loss=4.56
# Train: wpb=1000, num_updates=67000, accuracy=32.1, loss=4.56
# Train: wpb=1000, num_updates=68000, accuracy=32.1, loss=4.55
# Train: wpb=1000, num_updates=69000, accuracy=32.2, loss=4.54
# Train: wpb=1000, num_updates=70000, accuracy=32.3, loss=4.54
# Train: wpb=1000, num_updates=71000, accuracy=32.3, loss=4.53
# Train: wpb=1000, num_updates=72000, accuracy=32.4, loss=4.53
# Train: wpb=1000, num_updates=73000, accuracy=32.4, loss=4.52
# Train: wpb=1000, num_updates=74000, accuracy=32.5, loss=4.51
# Train: wpb=1000, num_updates=75000, accuracy=32.5, loss=4.51
# Train: wpb=1000, num_updates=76000, accuracy=32.6, loss=4.50
# Train: wpb=1000, num_updates=77000, accuracy=32.6, loss=4.50
# Train: wpb=1000, num_updates=78000, accuracy=32.7, loss=4.49
# Train: wpb=1000, num_updates=79000, accuracy=32.7, loss=4.49
# Train: wpb=1000, num_updates=80000, accuracy=32.8, loss=4.48
# Train: wpb=999, num_updates=80235, accuracy=32.8, loss=4.48
# | epoch 000 | train accuracy=32.8%, train loss=4.48
# | epoch 000 | valid accuracy=36.8%, valid loss=4.00 (wikipedia)
# | epoch 000 | valid accuracy=29.6%, valid loss=4.76 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=36.9, loss=3.98
# Train: wpb=1000, num_updates=500, accuracy=36.9, loss=3.98
# Train: wpb=1000, num_updates=1000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=2000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=3000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=4000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=5000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=6000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=7000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=8000, accuracy=36.8, loss=3.99
# Train: wpb=1000, num_updates=9000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=10000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=11000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=12000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=13000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=14000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=15000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=16000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=17000, accuracy=36.9, loss=3.99
# Train: wpb=1000, num_updates=18000, accuracy=37.0, loss=3.99
# Train: wpb=1000, num_updates=19000, accuracy=37.0, loss=3.99
# Train: wpb=1000, num_updates=20000, accuracy=37.0, loss=3.99
# Train: wpb=1000, num_updates=21000, accuracy=37.0, loss=3.99
# Train: wpb=1000, num_updates=22000, accuracy=37.0, loss=3.99
# Train: wpb=1000, num_updates=23000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=24000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=25000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=26000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=27000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=28000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=29000, accuracy=37.0, loss=3.98
# Train: wpb=1000, num_updates=30000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=31000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=32000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=33000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=34000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=35000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=36000, accuracy=37.1, loss=3.98
# Train: wpb=1000, num_updates=37000, accuracy=37.1, loss=3.97
# Train: wpb=1000, num_updates=38000, accuracy=37.1, loss=3.97
# Train: wpb=1000, num_updates=39000, accuracy=37.1, loss=3.97
# Train: wpb=1000, num_updates=40000, accuracy=37.1, loss=3.97
# Train: wpb=1000, num_updates=41000, accuracy=37.1, loss=3.97
# Train: wpb=1000, num_updates=42000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=43000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=44000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=45000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=46000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=47000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=48000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=49000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=50000, accuracy=37.2, loss=3.97
# Train: wpb=1000, num_updates=51000, accuracy=37.2, loss=3.96
# Train: wpb=1000, num_updates=52000, accuracy=37.2, loss=3.96
# Train: wpb=1000, num_updates=53000, accuracy=37.2, loss=3.96
# Train: wpb=1000, num_updates=54000, accuracy=37.2, loss=3.96
# Train: wpb=1000, num_updates=55000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=56000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=57000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=58000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=59000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=60000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=61000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=62000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=63000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=64000, accuracy=37.3, loss=3.96
# Train: wpb=1000, num_updates=65000, accuracy=37.3, loss=3.95
# Train: wpb=1000, num_updates=66000, accuracy=37.3, loss=3.95
# Train: wpb=1000, num_updates=67000, accuracy=37.3, loss=3.95
# Train: wpb=1000, num_updates=68000, accuracy=37.3, loss=3.95
# Train: wpb=1000, num_updates=69000, accuracy=37.3, loss=3.95
# Train: wpb=1000, num_updates=70000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=71000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=72000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=73000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=74000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=75000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=76000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=77000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=78000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=79000, accuracy=37.4, loss=3.95
# Train: wpb=1000, num_updates=80000, accuracy=37.4, loss=3.94
# Train: wpb=999, num_updates=80235, accuracy=37.4, loss=3.94
# | epoch 001 | train accuracy=37.4%, train loss=3.94
# | epoch 001 | valid accuracy=38.0%, valid loss=3.87 (wikipedia)
# | epoch 001 | valid accuracy=30.7%, valid loss=4.65 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=38.0, loss=3.83
# Train: wpb=1000, num_updates=500, accuracy=38.2, loss=3.82
# Train: wpb=1000, num_updates=1000, accuracy=38.2, loss=3.83
# Train: wpb=1000, num_updates=2000, accuracy=38.2, loss=3.83
# Train: wpb=1000, num_updates=3000, accuracy=38.3, loss=3.83
# Train: wpb=1000, num_updates=4000, accuracy=38.3, loss=3.83
# Train: wpb=1000, num_updates=5000, accuracy=38.3, loss=3.83
# Train: wpb=1000, num_updates=6000, accuracy=38.3, loss=3.83
# Train: wpb=1000, num_updates=7000, accuracy=38.2, loss=3.83
# Train: wpb=1000, num_updates=8000, accuracy=38.2, loss=3.83
# Train: wpb=1000, num_updates=9000, accuracy=38.2, loss=3.83
# Train: wpb=1000, num_updates=10000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=11000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=12000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=13000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=14000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=15000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=16000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=17000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=18000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=19000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=20000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=21000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=22000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=23000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=24000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=25000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=26000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=27000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=28000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=29000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=30000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=31000, accuracy=38.2, loss=3.84
# Train: wpb=1000, num_updates=32000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=33000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=34000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=35000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=36000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=37000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=38000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=39000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=40000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=41000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=42000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=43000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=44000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=45000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=46000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=47000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=48000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=49000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=50000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=51000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=52000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=53000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=54000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=55000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=56000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=57000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=58000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=59000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=60000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=61000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=62000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=63000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=64000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=65000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=66000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=67000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=68000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=69000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=70000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=71000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=72000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=73000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=74000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=75000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=76000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=77000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=78000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=79000, accuracy=38.3, loss=3.84
# Train: wpb=1000, num_updates=80000, accuracy=38.3, loss=3.84
# Train: wpb=999, num_updates=80235, accuracy=38.3, loss=3.84
# | epoch 002 | train accuracy=38.3%, train loss=3.84
# | epoch 002 | valid accuracy=38.5%, valid loss=3.81 (wikipedia)
# | epoch 002 | valid accuracy=30.9%, valid loss=4.62 (El Periódico)
# Train: wpb=1000, num_updates=200, accuracy=38.8, loss=3.76
# Train: wpb=1000, num_updates=500, accuracy=38.7, loss=3.76
# Train: wpb=1000, num_updates=1000, accuracy=38.8, loss=3.76
# Train: wpb=1000, num_updates=2000, accuracy=38.8, loss=3.76
# Train: wpb=1000, num_updates=3000, accuracy=38.8, loss=3.76
# Train: wpb=1000, num_updates=4000, accuracy=38.8, loss=3.76
# Train: wpb=1000, num_updates=5000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=6000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=7000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=8000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=9000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=10000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=11000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=12000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=13000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=14000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=15000, accuracy=38.8, loss=3.77
# Train: wpb=1000, num_updates=16000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=17000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=18000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=19000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=20000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=21000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=22000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=23000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=24000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=25000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=26000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=27000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=28000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=29000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=30000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=31000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=32000, accuracy=38.8, loss=3.78
# Train: wpb=1000, num_updates=33000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=34000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=35000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=36000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=37000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=38000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=39000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=40000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=41000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=42000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=43000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=44000, accuracy=38.7, loss=3.78
# Train: wpb=1000, num_updates=45000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=46000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=47000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=48000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=49000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=50000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=51000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=52000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=53000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=54000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=55000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=56000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=57000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=58000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=59000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=60000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=61000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=62000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=63000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=64000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=65000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=66000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=67000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=68000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=69000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=70000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=71000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=72000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=73000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=74000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=75000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=76000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=77000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=78000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=79000, accuracy=38.7, loss=3.79
# Train: wpb=1000, num_updates=80000, accuracy=38.7, loss=3.79
# Train: wpb=999, num_updates=80235, accuracy=38.7, loss=3.79
# | epoch 003 | train accuracy=38.7%, train loss=3.79
# | epoch 003 | valid accuracy=38.8%, valid loss=3.79 (wikipedia)
# | epoch 003 | valid accuracy=31.1%, valid loss=4.60 (El Periódico)

# %%
# 'El Periodico' test dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_test.csv')
test_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')
y_pred = validate(model, None, test_x, None, params.batch_size, device)
y_token = [vocab.idx2token[index] for index in y_pred]

# %%
submission = pd.DataFrame({'id':valid_x_df['id'], 'token': y_token}, columns=['id', 'token'])
print(submission.head())
submission.to_csv('submission.csv', index=False)
# Out:
#    id      token
# 0   0      <unk>
# 1   1      <unk>
# 2   2         la
# 3   3      <unk>
# 4   4  Assemblea
