# %%
from types import SimpleNamespace
from collections import Counter
import os
import re
import pathlib
import array
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import math

# %%
DATASET_VERSION = 'ca-100'
COMPETITION_ROOT = '../input/vectors'
DATASET_ROOT = f'../input/cbow-preprocessing/data/{DATASET_VERSION}'
WORKING_ROOT = f'data/{DATASET_VERSION}'
DATASET_PREFIX = 'ca.wiki'

# %%
params = SimpleNamespace(
    embedding_dim = 256,
    window_size = 5,
    batch_size = 2048,
    epochs = 4,
    preprocessed = f'{DATASET_ROOT}/{DATASET_PREFIX}',
    working = f'{WORKING_ROOT}/{DATASET_PREFIX}',
    modelname = f'{WORKING_ROOT}/{DATASET_VERSION}.pt',
    train = True
)

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    pathlib.Path('/content/drive/My Drive/POE/vectors').mkdir(parents=True, exist_ok=True)
    os.chdir('/content/drive/My Drive/POE/vectors')
except:
    pass

# %%
class Vocabulary(object):
    def __init__(self, pad_token='<pad>', unk_token='<unk>', eos_token='<eos>'):
        self.token2idx = {}
        self.idx2token = []
        self.pad_token = pad_token
        self.unk_token = unk_token
        self.eos_token = eos_token
        if pad_token is not None:
            self.pad_index = self.add_token(pad_token)
        if unk_token is not None:
            self.unk_index = self.add_token(unk_token)
        if eos_token is not None:
            self.eos_index = self.add_token(eos_token)

    def add_token(self, token):
        if token not in self.token2idx:
            self.idx2token.append(token)
            self.token2idx[token] = len(self.idx2token) - 1
        return self.token2idx[token]

    def get_index(self, token):
        if isinstance(token, str):
            return self.token2idx.get(token, self.unk_index)
        else:
            return [self.token2idx.get(t, self.unk_index) for t in token]

    def __len__(self):
        return len(self.idx2token)

    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.__dict__, f)

    def load(self, filename):
        with open(filename, 'rb') as f:
            self.__dict__.update(pickle.load(f))

# %%
def batch_generator(idata, target, batch_size, shuffle=True):
    nsamples = len(idata)
    if shuffle:
        perm = np.random.permutation(nsamples)
    else:
        perm = range(nsamples)

    for i in range(0, nsamples, batch_size):
        batch_idx = perm[i:i+batch_size]
        if target is not None:
            yield idata[batch_idx], target[batch_idx]
        else:
            yield idata[batch_idx], None

# %%
def load_preprocessed_dataset(prefix):
    # Try loading precomputed vocabulary and preprocessed data files
    token_vocab = Vocabulary()
    token_vocab.load(f'{prefix}.vocab')
    data = []
    for part in ['train', 'valid', 'test']:
        with np.load(f'{prefix}.{part}.npz') as set_data:
            idata, target = set_data['idata'], set_data['target']
            data.append((idata, target))
            print(f'Number of samples ({part}): {len(target)}')
    print("Using precomputed vocabulary and data files")
    print(f'Vocabulary size: {len(token_vocab)}')
    return token_vocab, data

# %%
def train(model, criterion, optimizer, idata, target, batch_size, device, log=False):
    model.train()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    for X, y in batch_generator(idata, target, batch_size, shuffle=True):
        # Get input and target sequences from batch
        X = torch.tensor(X, dtype=torch.long, device=device)
        y = torch.tensor(y, dtype=torch.long, device=device)

        model.zero_grad()
        output = model(X)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        # Training statistics
        total_loss += loss.item()
        ncorrect += (torch.max(output, 1)[1] == y).sum().item()
        ntokens += y.numel()
        niterations += 1
        if niterations == 200 or niterations == 500 or niterations % 1000 == 0:
            print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={100*ncorrect/ntokens:.1f}, loss={total_loss/ntokens:.2f}')

    total_loss = total_loss / ntokens
    accuracy = 100 * ncorrect / ntokens
    if log:
        print(f'Train: wpb={ntokens//niterations}, num_updates={niterations}, accuracy={accuracy:.1f}, loss={total_loss:.2f}')
    return accuracy, total_loss

# %%
def validate(model, criterion, idata, target, batch_size, device):
    model.eval()
    total_loss = 0
    ncorrect = 0
    ntokens = 0
    niterations = 0
    y_pred = []
    with torch.no_grad():
        for X, y in batch_generator(idata, target, batch_size, shuffle=False):
            # Get input and target sequences from batch
            X = torch.tensor(X, dtype=torch.long, device=device)
            output = model(X)
            if target is not None:
                y = torch.tensor(y, dtype=torch.long, device=device)
                loss = criterion(output, y)
                total_loss += loss.item()
                ncorrect += (torch.max(output, 1)[1] == y).sum().item()
                ntokens += y.numel()
                niterations += 1
            else:
                pred = torch.max(output, 1)[1].detach().to('cpu').numpy()
                y_pred.append(pred)

    if target is not None:
        total_loss = total_loss / ntokens
        accuracy = 100 * ncorrect / ntokens
        return accuracy, total_loss
    else:
        return np.concatenate(y_pred)

# %%
# Create working dir
pathlib.Path(WORKING_ROOT).mkdir(parents=True, exist_ok=True)

# %%
# Select device
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print("WARNING: Training without GPU can be very slow!")

# %%
vocab, data = load_preprocessed_dataset(params.preprocessed)
# Out:
# Number of samples (train): 80234403
# Number of samples (valid): 163012
# Number of samples (test): 164055
# Using precomputed vocabulary and data files
# Vocabulary size: 100002

# %%
# 'El Periodico' validation dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_valid.csv')
tokens = valid_x_df.columns[1:]
valid_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')
valid_y_df = pd.read_csv(f'{COMPETITION_ROOT}/y_valid.csv')
valid_y = valid_y_df['token'].apply(vocab.get_index).to_numpy(dtype='int32')

# %%
def attention(query, key, value, mask=None, dropout=None):
    "Compute 'Scaled Dot Product Attention'"
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -Inf)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

# %% [markdown]
# The **xavier_normal_()** initialization function fills the input Tensor with values according to the method described in **Understanding the difficulty of training deep feedforward neural networks** - Glorot, X. & Bengio, Y. (2010), using a uniform distribution. The resulting tensor will have values sampled from a uniform distribution \\(\mathcal{U}(-a, a)\\) where
#
# \\(    a = \text{gain} \times \sqrt{\frac{6}{\text{fan\_in} + \text{fan\_out}}}\\)
#
# Also known as Glorot initialization.

# %%
class SelfAttention(nn.Module):
    def __init__(self, embed_dim, bias=True):
        super().__init__()
        self.k_proj = nn.Linear(embed_dim, embed_dim, bias=bias)
        self.v_proj = nn.Linear(embed_dim, embed_dim, bias=bias)
        self.q_proj = nn.Linear(embed_dim, embed_dim, bias=bias)
        self.out_proj = nn.Linear(embed_dim, embed_dim, bias=bias)
        self.reset_parameters()

    def reset_parameters(self):
        # Empirically observed the convergence to be much better with the scaled initialization
        nn.init.xavier_uniform_(self.k_proj.weight, gain=1 / math.sqrt(2))
        nn.init.xavier_uniform_(self.v_proj.weight, gain=1 / math.sqrt(2))
        nn.init.xavier_uniform_(self.q_proj.weight, gain=1 / math.sqrt(2))
        nn.init.xavier_uniform_(self.out_proj.weight)
        if self.out_proj.bias is not None:
            nn.init.constant_(self.out_proj.bias, 0.)

    # B = Batch size
    # W = Number of context words (left + right)
    # E = embedding_dim
    def forward(self, x):
        # x shape is (B, W, E)
        q = self.q_proj(x)
        # q shape is (B, W, E)
        k = self.k_proj(x)
        # k shape is (B, W, E)
        v = self.v_proj(x)
        # k shape is (B, W, E)
        y, _ = attention(q, k, v)
        # y shape is (B, W, E)
        y = self.out_proj(y)
        # y shape is (B, W, E)
        return y

# %%
class TransformerLayer(nn.Module):
    def __init__(self, d_model, dim_feedforward=512, dropout=0.1, activation="relu"):
        super().__init__()
        self.self_attn = SelfAttention(d_model)
        # Implementation of Feedforward model
        self.linear1 = nn.Linear(d_model, dim_feedforward)
        self.dropout = nn.Dropout(dropout)
        self.linear2 = nn.Linear(dim_feedforward, d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, src):
        src2 = self.self_attn(src)
        src = src + self.dropout1(src2)
        src = self.norm1(src)
        src2 = self.linear2(self.dropout(F.relu(self.linear1(src))))
        src = src + self.dropout2(src2)
        src = self.norm2(src)
        return src

# %%
class Predictor(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, context_words=4):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lin = nn.Linear(embedding_dim, num_embeddings, bias=False)
        self.att = TransformerLayer(embedding_dim)
        self.position_embedding = nn.Parameter(torch.Tensor(context_words, embedding_dim))
        nn.init.xavier_uniform_(self.position_embedding)

    # B = Batch size
    # W = Number of context words (left + right)
    # E = embedding_dim
    # V = num_embeddings (number of words)
    def forward(self, input):
        # input shape is (B, W)
        e = self.emb(input)
        # e shape is (B, W, E)
        u = e + self.position_embedding
        # u shape is (B, W, E)
        v = self.att(u)
        # v shape is (B, W, E)
        x = v.sum(dim=1)
        # x shape is (B, E)
        W = self.emb.weight
        # W shape is (V, E)
        y = torch.matmul(x, W.transpose(0,1))
        # y shape is (B, V)
        return y

# %%
model = Predictor(len(vocab), params.embedding_dim).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(reduction='sum')

train_accuracy = []
wiki_accuracy = []
valid_accuracy = []
for epoch in range(params.epochs):
    acc, loss = train(model, criterion, optimizer, data[0][0], data[0][1], params.batch_size, device, log=True)
    train_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | train accuracy={acc:.1f}%, train loss={loss:.2f}')
    acc, loss = validate(model, criterion, data[1][0], data[1][1], params.batch_size, device)
    wiki_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (wikipedia)')
    acc, loss = validate(model, criterion, valid_x, valid_y, params.batch_size, device)
    valid_accuracy.append(acc)
    print(f'| epoch {epoch:03d} | valid accuracy={acc:.1f}%, valid loss={loss:.2f} (El Periódico)')

# Save model
torch.save(model.state_dict(), params.modelname)
# Out:
# Train: wpb=2048, num_updates=200, accuracy=1.8, loss=82.26
# Train: wpb=2048, num_updates=500, accuracy=2.3, loss=48.63
# Train: wpb=2048, num_updates=1000, accuracy=4.2, loss=30.14
# Train: wpb=2048, num_updates=2000, accuracy=7.9, loss=18.81
# Train: wpb=2048, num_updates=3000, accuracy=10.2, loss=14.84
# Train: wpb=2048, num_updates=4000, accuracy=11.9, loss=12.78
# Train: wpb=2048, num_updates=5000, accuracy=13.5, loss=11.48
# Train: wpb=2048, num_updates=6000, accuracy=15.0, loss=10.56
# Train: wpb=2048, num_updates=7000, accuracy=16.3, loss=9.87
# Train: wpb=2048, num_updates=8000, accuracy=17.5, loss=9.32
# Train: wpb=2048, num_updates=9000, accuracy=18.6, loss=8.88
# Train: wpb=2048, num_updates=10000, accuracy=19.5, loss=8.51
# Train: wpb=2048, num_updates=11000, accuracy=20.3, loss=8.20
# Train: wpb=2048, num_updates=12000, accuracy=21.1, loss=7.94
# Train: wpb=2048, num_updates=13000, accuracy=21.7, loss=7.71
# Train: wpb=2048, num_updates=14000, accuracy=22.3, loss=7.51
# Train: wpb=2048, num_updates=15000, accuracy=22.9, loss=7.33
# Train: wpb=2048, num_updates=16000, accuracy=23.4, loss=7.17
# Train: wpb=2048, num_updates=17000, accuracy=23.8, loss=7.02
# Train: wpb=2048, num_updates=18000, accuracy=24.3, loss=6.89
# Train: wpb=2048, num_updates=19000, accuracy=24.7, loss=6.77
# Train: wpb=2048, num_updates=20000, accuracy=25.1, loss=6.66
# Train: wpb=2048, num_updates=21000, accuracy=25.4, loss=6.56
# Train: wpb=2048, num_updates=22000, accuracy=25.8, loss=6.47
# Train: wpb=2048, num_updates=23000, accuracy=26.1, loss=6.39
# Train: wpb=2048, num_updates=24000, accuracy=26.4, loss=6.30
# Train: wpb=2048, num_updates=25000, accuracy=26.7, loss=6.23
# Train: wpb=2048, num_updates=26000, accuracy=27.0, loss=6.16
# Train: wpb=2048, num_updates=27000, accuracy=27.2, loss=6.09
# Train: wpb=2048, num_updates=28000, accuracy=27.5, loss=6.03
# Train: wpb=2048, num_updates=29000, accuracy=27.7, loss=5.97
# Train: wpb=2048, num_updates=30000, accuracy=27.9, loss=5.92
# Train: wpb=2048, num_updates=31000, accuracy=28.1, loss=5.86
# Train: wpb=2048, num_updates=32000, accuracy=28.3, loss=5.81
# Train: wpb=2048, num_updates=33000, accuracy=28.5, loss=5.77
# Train: wpb=2048, num_updates=34000, accuracy=28.7, loss=5.72
# Train: wpb=2048, num_updates=35000, accuracy=28.9, loss=5.68
# Train: wpb=2048, num_updates=36000, accuracy=29.1, loss=5.64
# Train: wpb=2048, num_updates=37000, accuracy=29.3, loss=5.60
# Train: wpb=2048, num_updates=38000, accuracy=29.4, loss=5.56
# Train: wpb=2048, num_updates=39000, accuracy=29.6, loss=5.52
# Train: wpb=2047, num_updates=39177, accuracy=29.6, loss=5.52
# | epoch 000 | train accuracy=29.6%, train loss=5.52
# | epoch 000 | valid accuracy=37.0%, valid loss=4.00 (wikipedia)
# | epoch 000 | valid accuracy=30.2%, valid loss=4.72 (El Periódico)
# Train: wpb=2048, num_updates=200, accuracy=35.8, loss=4.12
# Train: wpb=2048, num_updates=500, accuracy=35.8, loss=4.11
# Train: wpb=2048, num_updates=1000, accuracy=35.9, loss=4.11
# Train: wpb=2048, num_updates=2000, accuracy=35.9, loss=4.10
# Train: wpb=2048, num_updates=3000, accuracy=35.9, loss=4.10
# Train: wpb=2048, num_updates=4000, accuracy=36.0, loss=4.09
# Train: wpb=2048, num_updates=5000, accuracy=36.0, loss=4.09
# Train: wpb=2048, num_updates=6000, accuracy=36.1, loss=4.08
# Train: wpb=2048, num_updates=7000, accuracy=36.1, loss=4.08
# Train: wpb=2048, num_updates=8000, accuracy=36.1, loss=4.07
# Train: wpb=2048, num_updates=9000, accuracy=36.2, loss=4.07
# Train: wpb=2048, num_updates=10000, accuracy=36.2, loss=4.06
# Train: wpb=2048, num_updates=11000, accuracy=36.2, loss=4.06
# Train: wpb=2048, num_updates=12000, accuracy=36.3, loss=4.05
# Train: wpb=2048, num_updates=13000, accuracy=36.3, loss=4.05
# Train: wpb=2048, num_updates=14000, accuracy=36.3, loss=4.04
# Train: wpb=2048, num_updates=15000, accuracy=36.4, loss=4.04
# Train: wpb=2048, num_updates=16000, accuracy=36.4, loss=4.03
# Train: wpb=2048, num_updates=17000, accuracy=36.4, loss=4.03
# Train: wpb=2048, num_updates=18000, accuracy=36.5, loss=4.03
# Train: wpb=2048, num_updates=19000, accuracy=36.5, loss=4.02
# Train: wpb=2048, num_updates=20000, accuracy=36.5, loss=4.02
# Train: wpb=2048, num_updates=21000, accuracy=36.6, loss=4.01
# Train: wpb=2048, num_updates=22000, accuracy=36.6, loss=4.01
# Train: wpb=2048, num_updates=23000, accuracy=36.6, loss=4.00
# Train: wpb=2048, num_updates=24000, accuracy=36.7, loss=4.00
# Train: wpb=2048, num_updates=25000, accuracy=36.7, loss=4.00
# Train: wpb=2048, num_updates=26000, accuracy=36.7, loss=3.99
# Train: wpb=2048, num_updates=27000, accuracy=36.7, loss=3.99
# Train: wpb=2048, num_updates=28000, accuracy=36.8, loss=3.98
# Train: wpb=2048, num_updates=29000, accuracy=36.8, loss=3.98
# Train: wpb=2048, num_updates=30000, accuracy=36.8, loss=3.98
# Train: wpb=2048, num_updates=31000, accuracy=36.8, loss=3.97
# Train: wpb=2048, num_updates=32000, accuracy=36.9, loss=3.97
# Train: wpb=2048, num_updates=33000, accuracy=36.9, loss=3.97
# Train: wpb=2048, num_updates=34000, accuracy=36.9, loss=3.96
# Train: wpb=2048, num_updates=35000, accuracy=36.9, loss=3.96
# Train: wpb=2048, num_updates=36000, accuracy=37.0, loss=3.96
# Train: wpb=2048, num_updates=37000, accuracy=37.0, loss=3.95
# Train: wpb=2048, num_updates=38000, accuracy=37.0, loss=3.95
# Train: wpb=2048, num_updates=39000, accuracy=37.0, loss=3.95
# Train: wpb=2047, num_updates=39177, accuracy=37.0, loss=3.95
# | epoch 001 | train accuracy=37.0%, train loss=3.95
# | epoch 001 | valid accuracy=39.0%, valid loss=3.72 (wikipedia)
# | epoch 001 | valid accuracy=31.5%, valid loss=4.51 (El Periódico)
# Train: wpb=2048, num_updates=200, accuracy=38.1, loss=3.78
# Train: wpb=2048, num_updates=500, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=1000, accuracy=38.2, loss=3.79
# Train: wpb=2048, num_updates=2000, accuracy=38.1, loss=3.78
# Train: wpb=2048, num_updates=3000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=4000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=5000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=6000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=7000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=8000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=9000, accuracy=38.2, loss=3.78
# Train: wpb=2048, num_updates=10000, accuracy=38.2, loss=3.77
# Train: wpb=2048, num_updates=11000, accuracy=38.2, loss=3.77
# Train: wpb=2048, num_updates=12000, accuracy=38.2, loss=3.77
# Train: wpb=2048, num_updates=13000, accuracy=38.3, loss=3.77
# Train: wpb=2048, num_updates=14000, accuracy=38.3, loss=3.77
# Train: wpb=2048, num_updates=15000, accuracy=38.3, loss=3.77
# Train: wpb=2048, num_updates=16000, accuracy=38.3, loss=3.76
# Train: wpb=2048, num_updates=17000, accuracy=38.3, loss=3.76
# Train: wpb=2048, num_updates=18000, accuracy=38.3, loss=3.76
# Train: wpb=2048, num_updates=19000, accuracy=38.3, loss=3.76
# Train: wpb=2048, num_updates=20000, accuracy=38.3, loss=3.76
# Train: wpb=2048, num_updates=21000, accuracy=38.4, loss=3.76
# Train: wpb=2048, num_updates=22000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=23000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=24000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=25000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=26000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=27000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=28000, accuracy=38.4, loss=3.75
# Train: wpb=2048, num_updates=29000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=30000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=31000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=32000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=33000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=34000, accuracy=38.5, loss=3.74
# Train: wpb=2048, num_updates=35000, accuracy=38.5, loss=3.73
# Train: wpb=2048, num_updates=36000, accuracy=38.5, loss=3.73
# Train: wpb=2048, num_updates=37000, accuracy=38.5, loss=3.73
# Train: wpb=2048, num_updates=38000, accuracy=38.5, loss=3.73
# Train: wpb=2048, num_updates=39000, accuracy=38.6, loss=3.73
# Train: wpb=2047, num_updates=39177, accuracy=38.6, loss=3.73
# | epoch 002 | train accuracy=38.6%, train loss=3.73
# | epoch 002 | valid accuracy=39.9%, valid loss=3.61 (wikipedia)
# | epoch 002 | valid accuracy=32.0%, valid loss=4.43 (El Periódico)
# Train: wpb=2048, num_updates=200, accuracy=39.2, loss=3.64
# Train: wpb=2048, num_updates=500, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=1000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=2000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=3000, accuracy=39.2, loss=3.64
# Train: wpb=2048, num_updates=4000, accuracy=39.2, loss=3.64
# Train: wpb=2048, num_updates=5000, accuracy=39.2, loss=3.64
# Train: wpb=2048, num_updates=6000, accuracy=39.2, loss=3.64
# Train: wpb=2048, num_updates=7000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=8000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=9000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=10000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=11000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=12000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=13000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=14000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=15000, accuracy=39.2, loss=3.63
# Train: wpb=2048, num_updates=16000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=17000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=18000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=19000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=20000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=21000, accuracy=39.3, loss=3.63
# Train: wpb=2048, num_updates=22000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=23000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=24000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=25000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=26000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=27000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=28000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=29000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=30000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=31000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=32000, accuracy=39.3, loss=3.62
# Train: wpb=2048, num_updates=33000, accuracy=39.4, loss=3.62
# Train: wpb=2048, num_updates=34000, accuracy=39.4, loss=3.62
# Train: wpb=2048, num_updates=35000, accuracy=39.4, loss=3.61
# Train: wpb=2048, num_updates=36000, accuracy=39.4, loss=3.61
# Train: wpb=2048, num_updates=37000, accuracy=39.4, loss=3.61
# Train: wpb=2048, num_updates=38000, accuracy=39.4, loss=3.61
# Train: wpb=2048, num_updates=39000, accuracy=39.4, loss=3.61
# Train: wpb=2047, num_updates=39177, accuracy=39.4, loss=3.61
# | epoch 003 | train accuracy=39.4%, train loss=3.61
# | epoch 003 | valid accuracy=40.4%, valid loss=3.54 (wikipedia)
# | epoch 003 | valid accuracy=32.7%, valid loss=4.38 (El Periódico)

# %%
# 'El Periodico' test dataset
valid_x_df = pd.read_csv(f'{COMPETITION_ROOT}/x_test.csv')
test_x = valid_x_df[tokens].apply(vocab.get_index).to_numpy(dtype='int32')
y_pred = validate(model, None, test_x, None, params.batch_size, device)
y_token = [vocab.idx2token[index] for index in y_pred]

# %%
submission = pd.DataFrame({'id':valid_x_df['id'], 'token': y_token}, columns=['id', 'token'])
print(submission.head())
submission.to_csv('submission.csv', index=False)
# Out:
#    id      token
# 0   0      quals
# 1   1         ús
# 2   2         la
# 3   3      <unk>
# 4   4  Assemblea
